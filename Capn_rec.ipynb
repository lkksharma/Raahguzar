# %%
path = '/Users/ls/Desktop/Rec_Cap_data.xlsx'
import pandas as pd
df = pd.read_excel(path)

# %%
df
# Out:
#     Trip ID Captain ID  Model Class  Distance  Time Improv  Cargo Damage  \
# 0       101       A001            1       300         0.05          0.10
# 1       102       B003            1       310         0.04          0.08
# 2       103       A982            1       320         0.06          0.05
# 3       104       A923            1       330         0.04          0.09
# 4       105       A349            1       340         0.03          0.10
# 5       106       B293            1       350         0.04          0.08
# 6       107       C283            1       360         0.03          0.09
# 7       108       A234            1       305         0.04          0.08
# 8       109       A235            1       315         0.05          0.07
# 9       110       B473            1       320         0.06          0.05
# 10      111       B374            1       325         0.04          0.09
# 11      112       C384            1       330         0.03          0.10
# 12      113       B348            1       335         0.04          0.08
# 13      114       A388            1       340         0.03          0.07
# 14      201       A992            2       400         0.10          0.15
# 15      202       A001            2       420         0.12          0.12
# 16      203       C922            2       430         0.11          0.13
# 17      204        B29            2       440         0.09          0.12
# 18      205        B29            2       450         0.10          0.14
# 19      206       C283            2       460         0.09          0.15
# 20      207       A982            2       470         0.08          0.12
# 21      208       A982            2       400         0.10          0.12
# 22      209       B348            2       420         0.09          0.14
# 23      210       C283            2       430         0.11          0.13
# 24      211       C384            2       440         0.09          0.15
# 25      212       B374            2       450         0.08          0.14
# 26      213       B473            2       460         0.09          0.12
# 27      214       D733            2       470         0.10          0.13
# 28      301       A923            3       500         0.15          0.05
# 29      302       B973            3       520         0.18          0.04
# 30      303        K88            3       530         0.17          0.05
# 31      304       I939            3       540         0.16          0.06
# 32      305       L111            3       550         0.18          0.03
# 33      306       J928            3       560         0.15          0.04
# 34      307       A001            3       570         0.19          0.03
# 35      308       A233            3       500         0.15          0.05
# 36      309       B233            3       510         0.17          0.04
# 37      310       C922            3       530         0.16          0.06
# 38      311       D231            3       540         0.18          0.03
# 39      312       A388            3       550         0.16          0.05
# 40      313       A235            3       560         0.17          0.04
# 41      314       A992            3       570         0.18          0.03
# 42      315       A982            3       580         0.19          0.02
#
#     Ship Repairs  Fuel Used  Cap Exp  Trip Num  Cargo Type  Cargo Load  \
# 0           0.05        500        5         1     General        1000
# 1           0.07        520        4         1  Perishable         900
# 2           0.04        540        7         2     General         950
# 3           0.06        560        6         1     General        1000
# 4           0.05        580        5         1  Perishable        1100
# 5           0.07        600        6         1     General        1200
# 6           0.06        620        7         1     General        1300
# 7           0.05        510        6         1     General        1050
# 8           0.04        520        7         1  Perishable        1020
# 9           0.03        530        8         1     General        1080
# 10          0.05        540        5         2     General        1000
# 11          0.06        550        6         1  Perishable        1010
# 12          0.05        560        7         1     General        1005
# 13          0.04        570        9         1     General        1030
# 14          0.08        700        9         1     Fragile         800
# 15          0.06        750       10         2     Fragile         850
# 16          0.07        780        8         1     General        1100
# 17          0.09        800        7         2     General        1200
# 18          0.08        820        7         3  Perishable         900
# 19          0.07        850        9         2     General        1000
# 20          0.08        880       10         3     Fragile         950
# 21          0.07        690       10         2     Fragile         800
# 22          0.08        710        9         1     General        1150
# 23          0.06        720        8         1     General        1100
# 24          0.08        730        7         2     Fragile         950
# 25          0.07        750        9         1  Perishable        1000
# 26          0.06        770       10         1     General        1150
# 27          0.08        790        8         2     General        1120
# 28          0.02        600       10         2     General         900
# 29          0.01        620       12         1     Fragile         800
# 30          0.02        640       11         1     General         950
# 31          0.03        660        9         1     General        1000
# 32          0.01        680       12         1     Fragile         850
# 33          0.02        700       11         1     General         900
# 34          0.01        720       10         3     General        1100
# 35          0.02        600       10         2     General         900
# 36          0.01        620       12         1     Fragile         800
# 37          0.02        630        9         1     General         950
# 38          0.01        650       11         1     General        1000
# 39          0.02        680       12         1     Fragile         850
# 40          0.02        690       10         1     General         900
# 41          0.01        720       10         2     General        1100
# 42          0.01        740       11         2     Fragile         950
#
#     Incidents Rep  Ship Type  Prime Proba
# 0               2       Bulk         0.70
# 1               1  Container         0.60
# 2               2       Bulk         0.80
# 3               3       Bulk         0.50
# 4               4  Container         0.40
# 5               3       Bulk         0.60
# 6               2       Bulk         0.50
# 7               1       Bulk         0.65
# 8               2  Container         0.70
# 9               2       Bulk         0.75
# 10              3       Bulk         0.60
# 11              4  Container         0.55
# 12              2       Bulk         0.65
# 13              2       Bulk         0.70
# 14              5     Tanker         0.40
# 15              4     Tanker         0.50
# 16              3       Bulk         0.60
# 17              4       Bulk         0.50
# 18              5  Container         0.40
# 19              6       Bulk         0.30
# 20              4     Tanker         0.50
# 21              5     Tanker         0.40
# 22              4       Bulk         0.45
# 23              4       Bulk         0.50
# 24              6     Tanker         0.40
# 25              5  Container         0.35
# 26              3       Bulk         0.55
# 27              4       Bulk         0.50
# 28              1       Bulk         0.90
# 29              0     Tanker         0.95
# 30              1       Bulk         0.93
# 31              2       Bulk         0.90
# 32              0     Tanker         0.97
# 33              1       Bulk         0.91
# 34              0       Bulk         0.98
# 35              1       Bulk         0.90
# 36              0     Tanker         0.95
# 37              1       Bulk         0.93
# 38              2       Bulk         0.90
# 39              0     Tanker         0.97
# 40              1       Bulk         0.91
# 41              0       Bulk         0.98
# 42              0     Tanker         0.99

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df.columns
# Out:
# Index(['Trip ID', 'Captain ID', 'Model Class', 'Distance', 'Time Improv',
#        'Cargo Damage', 'Ship Repairs', 'Fuel Used', 'Cap Exp', 'Trip Num',
#        'Cargo Type', 'Cargo Load', 'Incidents Rep', 'Ship Type',
#        'Prime Proba'],
#       dtype='object')

# %%
# preproc = ColumnTransformer(transformers = [('hot', OneHotEncoder(), ['Captain ID','Cargo Type','Ship Type'])])

# %%
encoder = OneHotEncoder(sparse_output=False)
one_hot_encoded = encoder.fit_transform(df[['Captain ID','Cargo Type','Ship Type']])
one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(['Captain ID','Cargo Type','Ship Type']))
df_encoded = pd.concat([df, one_hot_df], axis=1)
df_encoded = df_encoded.drop(['Captain ID','Cargo Type','Ship Type'], axis=1)

# %%
data = df_encoded.drop(['Trip ID'], axis = 1)
x = df_encoded.drop(['Prime Proba'], axis = 1)

# %%
modelPipeline = (Pipeline(steps=[('classifier', RandomForestRegressor(n_estimators=100, random_state=42))]))

# %%
x_train, x_test, y_train, y_test = train_test_split(x, data['Prime Proba'], test_size = 0.3, random_state = 42)

# %%
modelPipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('classifier', RandomForestRegressor(random_state=42))])

# %%
y_pred = modelPipeline.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_pred,y_test)
# Out:
# 0.8932982310085625

# %%
y_tot_pred = modelPipeline.predict(x)

# %%
pred = pd.DataFrame(y_tot_pred)

# %%
df['Pred_Prob'] = y_tot_pred

# %%
df
# Out:
#     Trip ID Captain ID  Model Class  Distance  Time Improv  Cargo Damage  \
# 0       101       A001            1       300         0.05          0.10
# 1       102       B003            1       310         0.04          0.08
# 2       103       A982            1       320         0.06          0.05
# 3       104       A923            1       330         0.04          0.09
# 4       105       A349            1       340         0.03          0.10
# 5       106       B293            1       350         0.04          0.08
# 6       107       C283            1       360         0.03          0.09
# 7       108       A234            1       305         0.04          0.08
# 8       109       A235            1       315         0.05          0.07
# 9       110       B473            1       320         0.06          0.05
# 10      111       B374            1       325         0.04          0.09
# 11      112       C384            1       330         0.03          0.10
# 12      113       B348            1       335         0.04          0.08
# 13      114       A388            1       340         0.03          0.07
# 14      201       A992            2       400         0.10          0.15
# 15      202       A001            2       420         0.12          0.12
# 16      203       C922            2       430         0.11          0.13
# 17      204        B29            2       440         0.09          0.12
# 18      205        B29            2       450         0.10          0.14
# 19      206       C283            2       460         0.09          0.15
# 20      207       A982            2       470         0.08          0.12
# 21      208       A982            2       400         0.10          0.12
# 22      209       B348            2       420         0.09          0.14
# 23      210       C283            2       430         0.11          0.13
# 24      211       C384            2       440         0.09          0.15
# 25      212       B374            2       450         0.08          0.14
# 26      213       B473            2       460         0.09          0.12
# 27      214       D733            2       470         0.10          0.13
# 28      301       A923            3       500         0.15          0.05
# 29      302       B973            3       520         0.18          0.04
# 30      303        K88            3       530         0.17          0.05
# 31      304       I939            3       540         0.16          0.06
# 32      305       L111            3       550         0.18          0.03
# 33      306       J928            3       560         0.15          0.04
# 34      307       A001            3       570         0.19          0.03
# 35      308       A233            3       500         0.15          0.05
# 36      309       B233            3       510         0.17          0.04
# 37      310       C922            3       530         0.16          0.06
# 38      311       D231            3       540         0.18          0.03
# 39      312       A388            3       550         0.16          0.05
# 40      313       A235            3       560         0.17          0.04
# 41      314       A992            3       570         0.18          0.03
# 42      315       A982            3       580         0.19          0.02
#
#     Ship Repairs  Fuel Used  Cap Exp  Trip Num  Cargo Type  Cargo Load  \
# 0           0.05        500        5         1     General        1000
# 1           0.07        520        4         1  Perishable         900
# 2           0.04        540        7         2     General         950
# 3           0.06        560        6         1     General        1000
# 4           0.05        580        5         1  Perishable        1100
# 5           0.07        600        6         1     General        1200
# 6           0.06        620        7         1     General        1300
# 7           0.05        510        6         1     General        1050
# 8           0.04        520        7         1  Perishable        1020
# 9           0.03        530        8         1     General        1080
# 10          0.05        540        5         2     General        1000
# 11          0.06        550        6         1  Perishable        1010
# 12          0.05        560        7         1     General        1005
# 13          0.04        570        9         1     General        1030
# 14          0.08        700        9         1     Fragile         800
# 15          0.06        750       10         2     Fragile         850
# 16          0.07        780        8         1     General        1100
# 17          0.09        800        7         2     General        1200
# 18          0.08        820        7         3  Perishable         900
# 19          0.07        850        9         2     General        1000
# 20          0.08        880       10         3     Fragile         950
# 21          0.07        690       10         2     Fragile         800
# 22          0.08        710        9         1     General        1150
# 23          0.06        720        8         1     General        1100
# 24          0.08        730        7         2     Fragile         950
# 25          0.07        750        9         1  Perishable        1000
# 26          0.06        770       10         1     General        1150
# 27          0.08        790        8         2     General        1120
# 28          0.02        600       10         2     General         900
# 29          0.01        620       12         1     Fragile         800
# 30          0.02        640       11         1     General         950
# 31          0.03        660        9         1     General        1000
# 32          0.01        680       12         1     Fragile         850
# 33          0.02        700       11         1     General         900
# 34          0.01        720       10         3     General        1100
# 35          0.02        600       10         2     General         900
# 36          0.01        620       12         1     Fragile         800
# 37          0.02        630        9         1     General         950
# 38          0.01        650       11         1     General        1000
# 39          0.02        680       12         1     Fragile         850
# 40          0.02        690       10         1     General         900
# 41          0.01        720       10         2     General        1100
# 42          0.01        740       11         2     Fragile         950
#
#     Incidents Rep  Ship Type  Prime Proba  Pred_Prob
# 0               2       Bulk         0.70     0.6730
# 1               1  Container         0.60     0.6305
# 2               2       Bulk         0.80     0.7773
# 3               3       Bulk         0.50     0.6015
# 4               4  Container         0.40     0.5465
# 5               3       Bulk         0.60     0.6005
# 6               2       Bulk         0.50     0.6275
# 7               1       Bulk         0.65     0.6556
# 8               2  Container         0.70     0.6975
# 9               2       Bulk         0.75     0.7694
# 10              3       Bulk         0.60     0.6110
# 11              4  Container         0.55     0.5335
# 12              2       Bulk         0.65     0.6460
# 13              2       Bulk         0.70     0.6980
# 14              5     Tanker         0.40     0.3975
# 15              4     Tanker         0.50     0.4985
# 16              3       Bulk         0.60     0.5725
# 17              4       Bulk         0.50     0.5005
# 18              5  Container         0.40     0.4035
# 19              6       Bulk         0.30     0.3590
# 20              4     Tanker         0.50     0.4995
# 21              5     Tanker         0.40     0.4135
# 22              4       Bulk         0.45     0.4710
# 23              4       Bulk         0.50     0.4925
# 24              6     Tanker         0.40     0.3980
# 25              5  Container         0.35     0.4035
# 26              3       Bulk         0.55     0.5615
# 27              4       Bulk         0.50     0.4960
# 28              1       Bulk         0.90     0.9063
# 29              0     Tanker         0.95     0.9516
# 30              1       Bulk         0.93     0.9221
# 31              2       Bulk         0.90     0.8605
# 32              0     Tanker         0.97     0.9613
# 33              1       Bulk         0.91     0.9117
# 34              0       Bulk         0.98     0.9532
# 35              1       Bulk         0.90     0.9038
# 36              0     Tanker         0.95     0.9500
# 37              1       Bulk         0.93     0.8977
# 38              2       Bulk         0.90     0.9007
# 39              0     Tanker         0.97     0.9461
# 40              1       Bulk         0.91     0.9126
# 41              0       Bulk         0.98     0.9552
# 42              0     Tanker         0.99     0.9749

# %%
model_class = int(input("enter class"))
print('\033[1m'+"Recommendation:")
df[df['Pred_Prob']==(df[df.loc[:,'Model Class']==model_class]['Pred_Prob'].max())].loc[:,["Captain ID", "Ship Type", "Cargo Type"]]
# Out:
# enter class 2
# Recommendation:
#    Captain ID Ship Type Cargo Type
# 16       C922      Bulk    General
